# %%
# !pip install selenium
# Out:
# ...
# WARNING: You are using pip version 20.0.2; however, version 20.2.4 is available.
# You should consider upgrading via the 'c:\users\abubakar\anaconda3\envs\tfdeeplearning\python.exe -m pip install --upgrade pip' command.

# %%
import os
import sys
os.path.dirname(sys.executable)
# Out:
# 'C:\\Users\\Abubakar\\Anaconda3\\envs\\tfdeeplearning'

# %%
from time import sleep
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
# "webdriver.Chrome()"
driver = webdriver.Chrome()
driver.get('https://www.daraz.pk/products/head-shoulders-charcoal-detox-shampoo-200-ml-i116376017-s1268504511.html?spm=a2a0e.searchlist.list.1.17146f95kXrCk5&search=1')
df = pd.DataFrame(columns=['reviews'])
reviews
total_reviews=[]
sleep(5)
for q in range(20):
    
    sleep(6)
    for i in range(1,5):
        reviews = driver.find_element_by_css_selector('#module_product_review > div > div:nth-child(3) > div.mod-reviews > div:nth-child('+str(i)+') > div.item-content > div.content').text
        total_reviews.append(reviews)
    driver.find_element_by_css_selector('#module_product_review > div > div:nth-child(3) > div.next-pagination.next-pagination-normal.next-pagination-arrow-only.next-pagination-medium.medium.review-pagination > div > button.next-btn.next-btn-normal.next-btn-medium.next-pagination-item.next').click()
    #status = driver.find_element_by_css_selector("#module_product_review > div > div:nth-child(3) > div.next-pagination.next-pagination-normal.next-pagination-arrow-only.next-pagination-medium.medium.review-pagination > div > button.next-btn.next-btn-normal.next-btn-medium.next-pagination-item.next").is_selected()
    
    
driver.close()

# %%
for i in range(len(total_reviews)):
    df.loc[i]=total_reviews[i]

# %%
df
# Out:
#                                               reviews
# 0   Good Packaging Same As advertized and safely a...
# 1   Original shampoo,Good packing. Service was gre...
# 2   GREAT SERVICE , QUICK DELIVERY,\nORIGINAL PROD...
# 3   Ordered during Shopping September week and get...
# 4   This is the best products if you wash your hai...
# 5   daraz is best discount price me mila hai orgin...
# 6   Bubble Wrapped & Tape sealed , Well packed, De...
# 7   Very nice product and nice packing.\nTimely de...
# 8   head & Shoulders Charcoal Detox Shampoo is the...
# 9   Good and authentic delivery on time recommende...
# 10  Great packaging. Great product. Satisfied with...
# 11  A new flavor acha result he rather than other ...
# 12  Good and authentic delivery on time recommende...
# 13  Original product delivered, satisfied. Hairfal...
# 14  Good quality product at discounted price. Nice...
# 15                Orgnial product snd good packaging
# ...
